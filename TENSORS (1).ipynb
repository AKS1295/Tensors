# %%
import numpy as np

# %%
n1 = np.array([[34,65,7],[12,49,85]])
n1
# Out:
# array([[34, 65,  7],
#        [12, 49, 85]])

# %%
n2 = np.array([[70,11,24],[2,66,40]])
n2
# Out:
# array([[70, 11, 24],
#        [ 2, 66, 40]])

# %%
x = np.array([n1,n2])

# %%
x
# Out:
# array([[[34, 65,  7],
#         [12, 49, 85]],
#
#        [[70, 11, 24],
#         [ 2, 66, 40]]])

# %%
x.shape
# Out:
# (2, 2, 3)

# %%
x_manual = np.array([[[34,65,7],[12,49,85],[70,11,24],[2,66,40]]])

# %%
x_manual
# Out:
# array([[[34, 65,  7],
#         [12, 49, 85],
#         [70, 11, 24],
#         [ 2, 66, 40]]])

# %%
c1 = np.array([[4,65,74,2],[11,40,90,60]])
c1
# Out:
# array([[ 4, 65, 74,  2],
#        [11, 40, 90, 60]])

# %%
c2 = np.array([[1,5,7,9],[88,24,5,10]])
c2
# Out:
# array([[ 1,  5,  7,  9],
#        [88, 24,  5, 10]])

# %%
x =np.array([c1,c2])

# %%
x
# Out:
# array([[[ 4, 65, 74,  2],
#         [11, 40, 90, 60]],
#
#        [[ 1,  5,  7,  9],
#         [88, 24,  5, 10]]])

# %%
x.shape
# Out:
# (2, 2, 4)

# %%
x_manual = np.array([[[ 4, 65, 74,  2],[11, 40, 90, 60],[ 1,  5,  7,  9],[88, 24,  5, 10]]])

# %%
x_manual
# Out:
# array([[[ 4, 65, 74,  2],
#         [11, 40, 90, 60],
#         [ 1,  5,  7,  9],
#         [88, 24,  5, 10]]])
